# %% [markdown]
# # Perform basic input & output operation using Python

# %%
#this is a comment

# %%
#this is comment
#written in
#more than one line

# %%
#printing input
a=10
b="Pranjal"
print(a)
print(b)
# Out:
# 10
# Pranjal

# %%
#casting
a=str('Pranjal')
print(a)
b=int(7)
print(b)
# Out:
# Pranjal
# 7

# %%
#get the type
print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#single or double quote
a="Pranjal Mane"
b='Pranjal Mane'
print(a)
print(b)
# Out:
# Pranjal Mane
# Pranjal Mane

# %%
#Case-Sensitive
a=10
A="pranjal"
print(a)
print(A)
# Out:
# 10
# pranjal

# %%
s,p,q="Strawberry","Raspberry","Blueberry"
print(s)
print(p)
print(q)
# Out:
# Strawberry
# Raspberry
# Blueberry

# %%
s=q=p="Pineapple"
print(s)
print(q)
print(p)
# Out:
# Pineapple
# Pineapple
# Pineapple

# %%
Family=["Mummy ","Papa ","Chakuli ","Pranjal ","Aai "]
x,y,z,p,a=Family
print(x + y + z + p + a)
# Out:
# Mummy Papa Chakuli Pranjal Aai

# %%
a="my"
b="name"
c="is"
d="pranjal"
print(a ,b ,c ,d)
# Out:
# my name is pranjal

# %%
a="Pranjal"
b=19
print(a, b)
# Out:
# Pranjal 19

# %%
#arithmetic operators
a=10
b=5
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 15
# 5
# 2.0
# 50

# %%
#assignment operators
x=10
x+=5
print(x)
x-=5
print(x)
x*=5
print(x)
x/=5
print(x)
x%=5
print(x)
# Out:
# 15
# 10
# 50
# 10.0
# 0.0

# %%
num=11
x="Suyash!!" if num==11 else "Hurray"
print(x)
# Out:
# Suyash!!

# %%
num1 = 11
num2 = 7

print(num1==num2)
# Out:
# False

# %%
print(num1!=num2)
# Out:
# True

# %%
print(num1>=num2)
print(num1<=num2)
print(num1<num2)
print(num1>num2)
# Out:
# True
# False
# False
# True

# %%
a=11
print(a>10 and a<12)
# Out:
# True

# %%
print(a>10 or a<11)
# Out:
# True

# %%
print(not(a>10 and a<12))
# Out:
# False
